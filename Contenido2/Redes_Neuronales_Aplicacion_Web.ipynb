# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plot

# Red neuronal secuencial
from tensorflow.keras.models import Sequential
# Capa completamente conectada
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D
# Optimizador
from tensorflow.keras.optimizers import Adam

# %%
registros = 10000
a = np.random.randint(0, 10, registros)
b = np.random.randint(0, 10, registros)

c = a * 2 + b

# %%
data = pd.DataFrame({'a': a, 'b': b, 'c': c})

# %%
data.head(10)
# Out:
#    a  b   c
# 0  1  0   2
# 1  4  2  10
# 2  7  5  19
# 3  4  8  16
# 4  2  0   4
# 5  8  1  17
# 6  3  5  11
# 7  9  9  27
# 8  7  6  20
# 9  4  1   9

# %%
X = data[['a', 'b']]
y = data[['c']]

# %%
# Crear red neuronal
nn = Sequential([
    layers.Input(2),
    layers.Dense(8, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='relu')
])

# %%
nn.compile(
    loss='mean_absolute_error', # funcion de errror
    optimizer=Adam(0.001)   # optimizador
)

# %%
history = nn.fit(
    X,
    y,
    validation_split=0.2,
    verbose=1,
    epochs=10
)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 2s 3ms/step - loss: 5.2001 - val_loss: 0.8841
# Epoch 2/10
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3959 - val_loss: 0.1857
# Epoch 3/10
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1171 - val_loss: 0.0698
# Epoch 4/10
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0628 - val_loss: 0.0447
# Epoch 5/10
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0417 - val_loss: 0.0202
# Epoch 6/10
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0267 - val_loss: 0.0102
# Epoch 7/10
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0098
# Epoch 8/10
# 250/250 [==============================] - 0s 2ms/step - loss: 0.0172 - val_loss: 0.0249
# Epoch 9/10
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0143 - val_loss: 0.0151
# Epoch 10/10
# ...

# %%
prediccion = nn.predict(np.array([[5, 4]]))
print(prediccion)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[14.009485]]

# %%
nn.save('/content/regresion.h5')
